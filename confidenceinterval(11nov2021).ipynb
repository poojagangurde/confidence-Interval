# %%
import pandas as pd
import numpy as np

# %%
beml_df=pd.read_csv("E:\\notebooks file\\BEML.csv")
glaxo_df=pd.read_csv("E:\\notebooks file\\GLAXO.csv")

# %%
beml_df.head()
# Out:
#          Date    Open     High      Low    Last    Close  \
# 0  04-01-2010  1121.0  1151.00  1121.00  1134.0  1135.60
# 1  05-01-2010  1146.8  1149.00  1128.75  1135.0  1134.60
# 2  06-01-2010  1140.0  1164.25  1130.05  1137.0  1139.60
# 3  07-01-2010  1142.0  1159.40  1119.20  1141.0  1144.15
# 4  08-01-2010  1156.0  1172.00  1140.00  1141.2  1144.05
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                101651          1157.18
# 1                 59504           676.47
# 2                128908          1482.84
# 3                117871          1352.98
# 4                170063          1971.42

# %%
glaxo_df[0:5]
# Out:
#          Date     Open     High      Low    Last    Close  \
# 0  04-01-2010  1613.00  1629.10  1602.00  1629.0  1625.65
# 1  05-01-2010  1639.95  1639.95  1611.05  1620.0  1616.80
# 2  06-01-2010  1618.00  1644.00  1617.00  1639.0  1638.50
# 3  07-01-2010  1645.00  1654.00  1636.00  1648.0  1648.70
# 4  08-01-2010  1650.00  1650.00  1626.55  1640.0  1639.80
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                  9365           151.74
# 1                 38148           622.58
# 2                 36519           595.09
# 3                 12809           211.00
# 4                 28035           459.11

# %%
beml_df=beml_df[['Date','Close']]
glaxo_df=glaxo_df[['Date','Close']]

# %%
beml_df
# Out:
#             Date    Close
# 0     04-01-2010  1135.60
# 1     05-01-2010  1134.60
# 2     06-01-2010  1139.60
# 3     07-01-2010  1144.15
# 4     08-01-2010  1144.05
# ...          ...      ...
# 1734  26-12-2016   950.25
# 1735  27-12-2016   975.70
# 1736  28-12-2016   974.40
# 1737  29-12-2016   986.05
# 1738  30-12-2016  1000.60
#
# [1739 rows x 2 columns]

# %%
glaxo_df
# Out:
#             Date    Close
# 0     04-01-2010  1625.65
# 1     05-01-2010  1616.80
# 2     06-01-2010  1638.50
# 3     07-01-2010  1648.70
# 4     08-01-2010  1639.80
# ...          ...      ...
# 1734  26-12-2016  2723.50
# 1735  27-12-2016  2701.75
# 1736  28-12-2016  2702.15
# 1737  29-12-2016  2727.90
# 1738  30-12-2016  2729.80
#
# [1739 rows x 2 columns]

# %%
beml_df=beml_df.set_index(pd.DatetimeIndex(beml_df['Date']))

# %%
glaxo_df=glaxo_df.set_index(pd.DatetimeIndex(glaxo_df['Date']))

# %%
beml_df
# Out:
#                   Date    Close
# Date
# 2010-04-01  04-01-2010  1135.60
# 2010-05-01  05-01-2010  1134.60
# 2010-06-01  06-01-2010  1139.60
# 2010-07-01  07-01-2010  1144.15
# 2010-08-01  08-01-2010  1144.05
# ...                ...      ...
# 2016-12-26  26-12-2016   950.25
# 2016-12-27  27-12-2016   975.70
# 2016-12-28  28-12-2016   974.40
# 2016-12-29  29-12-2016   986.05
# 2016-12-30  30-12-2016  1000.60
#
# [1739 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(8,6))
plt.plot(beml_df.Close);
plt.xlabel('Time');
plt.ylabel('Close price')
# Out:
# Text(0, 0.5, 'Close price')

# %%
plt.figure(figsize=(8,6))
plt.plot(glaxo_df.Close);
plt.xlabel('Time');
plt.ylabel('Close price')
# Out:
# Text(0, 0.5, 'Close price')

# %%
beml_df['gain']=beml_df.Close.pct_change(periods=1)
glaxo_df['gain']=glaxo_df.Close.pct_change(periods=1)

# %%
beml_df
# Out:
#                   Date    Close      gain
# Date
# 2010-04-01  04-01-2010  1135.60       NaN
# 2010-05-01  05-01-2010  1134.60 -0.000881
# 2010-06-01  06-01-2010  1139.60  0.004407
# 2010-07-01  07-01-2010  1144.15  0.003993
# 2010-08-01  08-01-2010  1144.05 -0.000087
# ...                ...      ...       ...
# 2016-12-26  26-12-2016   950.25 -0.021924
# 2016-12-27  27-12-2016   975.70  0.026782
# 2016-12-28  28-12-2016   974.40 -0.001332
# 2016-12-29  29-12-2016   986.05  0.011956
# 2016-12-30  30-12-2016  1000.60  0.014756
#
# [1739 rows x 3 columns]

# %%
glaxo_df
# Out:
#                   Date    Close      gain
# Date
# 2010-04-01  04-01-2010  1625.65       NaN
# 2010-05-01  05-01-2010  1616.80 -0.005444
# 2010-06-01  06-01-2010  1638.50  0.013422
# 2010-07-01  07-01-2010  1648.70  0.006225
# 2010-08-01  08-01-2010  1639.80 -0.005398
# ...                ...      ...       ...
# 2016-12-26  26-12-2016  2723.50 -0.001283
# 2016-12-27  27-12-2016  2701.75 -0.007986
# 2016-12-28  28-12-2016  2702.15  0.000148
# 2016-12-29  29-12-2016  2727.90  0.009529
# 2016-12-30  30-12-2016  2729.80  0.000697
#
# [1739 rows x 3 columns]

# %%
beml_df=beml_df.dropna()

# %%
glaxo_df=glaxo_df.dropna()

# %%
plt.plot(beml_df.index,beml_df.gain);
plt.xlabel('time');
plt.ylabel('gain')
# Out:
# Text(0, 0.5, 'gain')

# %%
plt.plot(glaxo_df.index,glaxo_df.gain);
plt.xlabel('time');
plt.ylabel('gain')
# Out:
# Text(0, 0.5, 'gain')

# %%
import seaborn as sns

# %%
sns.distplot(beml_df.gain,label='Beml');
plt.xlabel('gain');
plt.ylabel('density')
# Out:
# C:\Users\Server\AppData\Local\Temp\ipykernel_4408\335085605.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(beml_df.gain,label='Beml');
# Text(0, 0.5, 'density')

# %%
sns.distplot(glaxo_df.gain,label='Glaxo');
plt.xlabel('gain');
plt.ylabel('density')
# Out:
# C:\Users\Server\AppData\Local\Temp\ipykernel_4408\2917899909.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(glaxo_df.gain,label='Glaxo');
# Text(0, 0.5, 'density')

# %%
round(beml_df.gain.mean(),4)
# Out:
# 0.0003

# %%
round(beml_df.gain.std(),4)
# Out:
# 0.0264

# %%
round(glaxo_df.gain.mean(),4)
# Out:
# 0.0004

# %%
round(glaxo_df.gain.std(),4)
# Out:
# 0.0134

# %%
from scipy import stats

# %%
stats.norm.cdf(-0.02,loc=beml_df.gain.mean(),scale=beml_df.gain.std())
# Out:
# 0.22155987503755287

# %%
1-stats.norm.cdf(0.02,loc=beml_df.gain.mean(),scale=beml_df.gain.std())
# Out:
# 0.22769829484075355

# %%
stats.norm.cdf(-0.02,loc=glaxo_df.gain.mean(),scale=glaxo_df.gain.std())
# Out:
# 0.06352488667177397

# %%
1-stats.norm.cdf(0.02,loc=glaxo_df.gain.mean(),scale=glaxo_df.gain.std())
# Out:
# 0.07104511457618568

# %%
glaxo_df_ci=stats.norm.interval(0.95,loc=glaxo_df.gain.mean(),scale=glaxo_df.gain.std())

# %%
np.round(glaxo_df_ci,4)
# Out:
# array([-0.0258,  0.0266])

# %%
beml_df_ci=stats.norm.interval(0.95,loc=beml_df.gain.mean(),scale=beml_df.gain.std())
np.round(beml_df_ci,4)
# Out:
# array([-0.0515,  0.0521])

# %%
stats.norm.ppf(0.975)
# Out:
# 1.959963984540054

# %%
stats.norm.cdf(680,711,29)
# Out:
# 0.14254260383881612

# %%
a=stats.norm.cdf(697,711,29)

# %%
b=stats.norm.cdf(740,711,29)

# %%
b-a
# Out:
# 0.5267111786415019

# %%
from scipy.stats import t

# %%
t.interval(0.95,10,loc=0.0003,scale=0.0264)
# Out:
# (-0.05852286569187438, 0.05912286569187438)

# %%
stats.norm.ppf(0.95)
# Out:
# 1.6448536269514722

# %%
stats.norm.interval(0.95,loc=0.0003,scale=0.0264)
# Out:
# (-0.05144304919185742, 0.05204304919185743)
